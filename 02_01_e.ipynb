# %% [markdown]
# ## 02_01 Multi Agent Conversation

# %%
## import required libraries
import os
from autogen import ConversableAgent
from dotenv import load_dotenv


load_dotenv() # load environment variables from .env file
# Out:
# True

# %%
config_list = [
            {
                "model": "gpt-4o",
                "api_key": os.getenv("OPENAI_API_KEY")
            }
        ]

# %% [markdown]
# ## Conversation between student and tutor agent

# %%
# Create a student agent
student = ConversableAgent(
    "student",
    system_message="You are a high school student struggling with algebra. You need help understanding quadratic equations.",
    llm_config={
        "config_list": config_list
    },
    human_input_mode="NEVER"
)
# Out:
# [autogen.oai.client: 09-28 01:32:46] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.

# %%
# Create a tutor agent
tutor = ConversableAgent(
    "tutor",
    system_message="You are a patient and knowledgeable math tutor. Your goal is to help students understand algebra concepts, particularly quadratic equations.",
    llm_config={
        "config_list": config_list
    },
    human_input_mode="NEVER"
)
# Out:
# [autogen.oai.client: 09-28 01:33:13] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.

# %%
## start a learning session
result = student.initiate_chat(
    recipient=tutor,
    message="I'm really struggling with quadratic equations. Can you help me understand them better?",
    max_turns=2
)
# Out:
# student (to tutor):
#
# I'm really struggling with quadratic equations. Can you help me understand them better?
#
# --------------------------------------------------------------------------------
# tutor (to student):
#
# Of course, I'd be happy to help! Quadratic equations can seem complex at first, but once you break them down, they become much more manageable. Let's go through the basics together.
#
# ### What is a Quadratic Equation?
#
# A quadratic equation is a second-degree polynomial equation in one variable. The general form is:
# \[ ax^2 + bx + c = 0 \]
# where:
# - \( a \), \( b \), and \( c \) are constants (with \( a \neq 0 \)),
# - \( x \) is the variable.
#
# ### Basic Concepts
#
# 1. **Standard Form**: The equation \( ax^2 + bx + c = 0 \) should be arranged so that all terms are on one side and zero on the other side.
#
# 2. **Solutions/Roots**: Solutions to the quadratic equation are the values of \( x \) that make the equation true. A quadratic equation can have two, one, or no real solutions.
#
# ### Methods to Solve Quadratic Equations
#
# There are several methods to solve a quadratic equation:
#
# 1. **Factoring**:
#    - This involves rewriting the equation as a product of two binomials. For example:
#      \(x^2 - 5x + 6 = (x - 2)(x - 3) = 0\)
#    - Setting each factor to zero gives you the solutions: \(x - 2 = 0\) and \(x - 3 = 0\) results in \(x = 2\) and \(x = 3\).
#
# 2. **Completing the Square**:
#    - Rewrite the equation in the form \((x - p)^2 = q\), then solve for \(x\).
#    - For example: \( x^2 + 6x + 5 = 0 \)
#      First, move the constant term to the other side: \( x^2 + 6x = -5 \)
#      Next, add \((b/2)^2\) to both sides, where \(b\) is the coefficient of \(x\):
#      \( x^2 + 6x + 9 = -5 + 9 \)
#      \( (x + 3)^2 = 4 \)
#      Take the square root of both sides: \( x + 3 = \pm 2 \)
#      Finally, solve for \(x\): \( x = -3 \pm 2 \), so \( x = -1 \) or \( x = -5 \).
#
# 3. **Quadratic Formula**:
#    - This is a formula that provides the solutions directly. It is:
#      \[
#      x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
#      \]
#    - For example, if \(a = 1\), \(b = -3\), and \(c = 2\):
#      \[
#      x = \frac{-(-3) \pm \sqrt{(-3)^2 - 4 \cdot 1 \cdot 2}}{2 \cdot 1}
#      = \frac{3 \pm \sqrt{9 - 8}}{2}
#      = \frac{3 \pm 1}{2}
#      \]
#      So, \(x = \frac{4}{2} = 2 \) or \(x = \frac{2}{2} = 1\).
#
# 4. **Graphing**:
#    - Quadratic equations represent parabolas when graphed. The solutions are the x-values where the parabola intersects the x-axis (the roots of the equation).
#
# ### Discriminant
#
# The discriminant in the quadratic equation is \( \Delta = b^2 - 4ac \):
# - If \( \Delta > 0 \), there are two distinct real solutions.
# - If \( \Delta = 0 \), there is one real solution.
# - If \( \Delta < 0 \), there are no real solutions, but two complex solutions.
#
# Would you like to work through a specific example together to see how these methods are applied?
#
# --------------------------------------------------------------------------------
# student (to tutor):
#
# Sure, I'd be happy to help! Quadratic equations can seem complex at first, but once you break them down, they become much more manageable. Let's go through the basics together.
#
# ### What is a Quadratic Equation?
#
# A quadratic equation is a second-degree polynomial equation in one variable. The general form is:
# \[ ax^2 + bx + c = 0 \]
# where:
# - \( a \), \( b \), and \( c \) are constants (with \( a \neq 0 \)),
# - \( x \) is the variable.
#
# ### Basic Concepts
#
# 1. **Standard Form**: The equation \( ax^2 + bx + c = 0 \) should be arranged so that all terms are on one side and zero on the other side.
#
# 2. **Solutions/Roots**: Solutions to the quadratic equation are the values of \( x \) that make the equation true. A quadratic equation can have two, one, or no real solutions.
#
# ### Methods to Solve Quadratic Equations
#
# There are several methods to solve a quadratic equation:
#
# 1. **Factoring**:
#    - This involves rewriting the equation as a product of two binomials. For example:
#      \[x^2 - 5x + 6 = (x - 2)(x - 3) = 0\]
#    - Setting each factor to zero gives you the solutions: \(x - 2 = 0\) and \(x - 3 = 0\) results in \(x = 2\) and \(x = 3\).
#
# 2. **Completing the Square**:
#    - Rewrite the equation in the form \((x - p)^2 = q\), then solve for \(x\).
#    - For example: \( x^2 + 6x + 5 = 0 \)
#      First, move the constant term to the other side: \( x^2 + 6x = -5 \)
#      Next, add \((\frac{b}{2})^2\) to both sides, where \(b\) is the coefficient of \(x\):
#      \( x^2 + 6x + 9 = -5 + 9 \)
#      \( (x + 3)^2 = 4 \)
#      Take the square root of both sides: \( x + 3 = \pm 2 \)
#      Finally, solve for \(x\): \( x = -3 \pm 2 \), so \( x = -1 \) or \( x = -5 \).
#
# 3. **Using the Quadratic Formula**:
#    - This is a formula that provides the solutions directly. It is:
#      \[
#      x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
#      \]
#    - For example, if \(a = 1\), \(b = -3\), and \(c = 2\):
#      \[
#      x = \frac{-(-3) \pm \sqrt{(-3)^2 - 4 \cdot 1 \cdot 2}}{2 \cdot 1}
#      = \frac{3 \pm \sqrt{9 - 8}}{2}
#      = \frac{3 \pm 1}{2}
#      \]
#      So, \(x = \frac{4}{2} = 2 \) or \(x = \frac{2}{2} = 1\).
#
# 4. **Graphing**:
#    - Quadratic equations represent parabolas when graphed. The solutions are the x-values where the parabola intersects the x-axis (the roots of the equation).
#
# ### Discriminant
#
# The discriminant in the quadratic equation is \( \Delta = b^2 - 4ac \):
# - If \( \Delta > 0 \), there are two distinct real solutions.
# - If \( \Delta = 0 \), there is one real solution.
# - If \( \Delta < 0 \), there are no real solutions, but two complex solutions.
#
# Would you like to work through a specific example together to see how these methods are applied?
#
# --------------------------------------------------------------------------------
# tutor (to student):
#
# Absolutely, let's work through a specific example together. How about we solve the quadratic equation \(2x^2 - 4x - 6 = 0\)? We'll apply the methods we've discussed to solve it.
#
# ### Step-by-Step Example
#
# #### 1. Factoring
# Factoring can occasionally be more challenging if the equation doesn't easily break down into binomials. In this particular equation, factoring isn't straightforward, so let's move on to another method.
#
# #### 2. Completing the Square
#
# To complete the square, we start by rearranging the equation:
#
# \[ 2x^2 - 4x - 6 = 0 \]
#
# First, divide every term by \(2\) to simplify the equation:
#
# \[ x^2 - 2x - 3 = 0 \]
#
# Next, move the constant term to the other side:
#
# \[ x^2 - 2x = 3 \]
#
# Now add \((\frac{b}{2})^2\) to both sides, where \(b = -2\):
#
# \[ x^2 - 2x + 1 = 3 + 1 \]
#
# Notice how we turned the left side into a perfect square trinomial:
#
# \[ (x - 1)^2 = 4 \]
#
# To solve for \(x\), take the square root of both sides:
#
# \[ x - 1 = \pm 2 \]
#
# Thus, \(x\) can be:
#
# \[ x - 1 = 2 \implies x = 3 \]
# \[ x - 1 = -2 \implies x = -1 \]
#
# So, the solutions are \(x = 3\) and \(x = -1\).
#
# #### 3. Using the Quadratic Formula
#
# Now let's apply the quadratic formula:
#
# \[ x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} \]
#
# Given our original equation \(2x^2 - 4x - 6 = 0\), identify the coefficients \(a = 2\), \(b = -4\), and \(c = -6\):
#
# \[ x = \frac{-(-4) \pm \sqrt{(-4)^2 - 4 \cdot 2 \cdot (-6)}}{2 \cdot 2} \]
#
# Simplify inside the square root:
#
# \[ x = \frac{4 \pm \sqrt{16 + 48}}{4} \]
# \[ x = \frac{4 \pm \sqrt{64}}{4} \]
# \[ x = \frac{4 \pm 8}{4} \]
#
# This gives us two solutions:
#
# \[ x = \frac{4 + 8}{4} = \frac{12}{4} = 3 \]
# \[ x = \frac{4 - 8}{4} = \frac{-4}{4} = -1 \]
#
# So, the solutions are indeed \(x = 3\) and \(x = -1\), consistent with our previous method.
#
# #### 4. Graphing
#
# When we graph \(2x^2 - 4x - 6 = 0\), we would plot the parabola represented by the equation \(y = 2x^2 - 4x - 6\). The points where the parabola intersects the x-axis will be at \(x = 3\) and \(x = -1\).
#
# ### Summary
#
# We've verified that the solutions to the quadratic equation \(2x^2 - 4x - 6 = 0\) are \(x = 3\) and \(x = -1\) using both completing the square and the quadratic formula. Factoring didn't work straightforwardly, which can happen, but you always have multiple tools to tackle these problems.
#
# Would you like to go through another example or have any specific questions about what we covered?
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Printing results

# %%
import pprint

pprint.pprint(result.chat_history)
# Out:
# [{'content': "I'm really struggling with quadratic equations. Can you help me "
#              'understand them better?',
#   'role': 'assistant'},
#  {'content': "Of course, I'd be happy to help! Quadratic equations can seem "
#              'complex at first, but once you break them down, they become much '
#              "more manageable. Let's go through the basics together.\n"
#              '\n'
#              '### What is a Quadratic Equation?\n'
#              '\n'
#              'A quadratic equation is a second-degree polynomial equation in '
#              'one variable. The general form is:\n'
#              '\\[ ax^2 + bx + c = 0 \\]\n'
#              'where:\n'
#              '- \\( a \\), \\( b \\), and \\( c \\) are constants (with \\( a '
#              '\\neq 0 \\)),\n'
#              '- \\( x \\) is the variable.\n'
#              '\n'
#              '### Basic Concepts\n'
#              '\n'
#              '1. **Standard Form**: The equation \\( ax^2 + bx + c = 0 \\) '
#              'should be arranged so that all terms are on one side and zero on '
#              'the other side.\n'
#              '   \n'
#              '2. **Solutions/Roots**: Solutions to the quadratic equation are '
#              'the values of \\( x \\) that make the equation true. A quadratic '
#              'equation can have two, one, or no real solutions.\n'
#              '\n'
#              '### Methods to Solve Quadratic Equations\n'
#              '\n'
#              'There are several methods to solve a quadratic equation:\n'
#              '\n'
#              '1. **Factoring**: \n'
#              '   - This involves rewriting the equation as a product of two '
#              'binomials. For example: \n'
#              '     \\(x^2 - 5x + 6 = (x - 2)(x - 3) = 0\\)\n'
#              '   - Setting each factor to zero gives you the solutions: \\(x - '
#              '2 = 0\\) and \\(x - 3 = 0\\) results in \\(x = 2\\) and \\(x = '
#              '3\\).\n'
#              '\n'
#              '2. **Completing the Square**:\n'
#              '   - Rewrite the equation in the form \\((x - p)^2 = q\\), then '
#              'solve for \\(x\\).\n'
#              '   - For example: \\( x^2 + 6x + 5 = 0 \\)\n'
#              '     First, move the constant term to the other side: \\( x^2 + '
#              '6x = -5 \\)\n'
#              '     Next, add \\((b/2)^2\\) to both sides, where \\(b\\) is the '
#              'coefficient of \\(x\\): \n'
#              '     \\( x^2 + 6x + 9 = -5 + 9 \\)\n'
#              '     \\( (x + 3)^2 = 4 \\)\n'
#              '     Take the square root of both sides: \\( x + 3 = \\pm 2 \\)\n'
#              '     Finally, solve for \\(x\\): \\( x = -3 \\pm 2 \\), so \\( x '
#              '= -1 \\) or \\( x = -5 \\).\n'
#              '\n'
#              '3. **Quadratic Formula**:\n'
#              '   - This is a formula that provides the solutions directly. It '
#              'is:\n'
#              '     \\[\n'
#              '     x = \\frac{-b \\pm \\sqrt{b^2 - 4ac}}{2a}\n'
#              '     \\]\n'
#              '   - For example, if \\(a = 1\\), \\(b = -3\\), and \\(c = '
#              '2\\):\n'
#              '     \\[\n'
#              '     x = \\frac{-(-3) \\pm \\sqrt{(-3)^2 - 4 \\cdot 1 \\cdot '
#              '2}}{2 \\cdot 1} \n'
#              '     = \\frac{3 \\pm \\sqrt{9 - 8}}{2} \n'
#              '     = \\frac{3 \\pm 1}{2}\n'
#              '     \\]\n'
#              '     So, \\(x = \\frac{4}{2} = 2 \\) or \\(x = \\frac{2}{2} = '
#              '1\\).\n'
#              '\n'
#              '4. **Graphing**:\n'
#              '   - Quadratic equations represent parabolas when graphed. The '
#              'solutions are the x-values where the parabola intersects the '
#              'x-axis (the roots of the equation).\n'
#              '\n'
#              '### Discriminant\n'
#              '\n'
#              'The discriminant in the quadratic equation is \\( \\Delta = b^2 '
#              '- 4ac \\):\n'
#              '- If \\( \\Delta > 0 \\), there are two distinct real '
#              'solutions.\n'
#              '- If \\( \\Delta = 0 \\), there is one real solution.\n'
#              '- If \\( \\Delta < 0 \\), there are no real solutions, but two '
#              'complex solutions.\n'
#              '\n'
#              'Would you like to work through a specific example together to '
#              'see how these methods are applied?',
#   'role': 'user'},
#  {'content': "Sure, I'd be happy to help! Quadratic equations can seem complex "
#              'at first, but once you break them down, they become much more '
#              "manageable. Let's go through the basics together.\n"
#              '\n'
#              '### What is a Quadratic Equation?\n'
#              '\n'
#              'A quadratic equation is a second-degree polynomial equation in '
#              'one variable. The general form is:\n'
#              '\\[ ax^2 + bx + c = 0 \\]\n'
#              'where:\n'
#              '- \\( a \\), \\( b \\), and \\( c \\) are constants (with \\( a '
#              '\\neq 0 \\)),\n'
#              '- \\( x \\) is the variable.\n'
#              '\n'
#              '### Basic Concepts\n'
#              '\n'
#              '1. **Standard Form**: The equation \\( ax^2 + bx + c = 0 \\) '
#              'should be arranged so that all terms are on one side and zero on '
#              'the other side.\n'
#              '   \n'
#              '2. **Solutions/Roots**: Solutions to the quadratic equation are '
#              'the values of \\( x \\) that make the equation true. A quadratic '
#              'equation can have two, one, or no real solutions.\n'
#              '\n'
#              '### Methods to Solve Quadratic Equations\n'
#              '\n'
#              'There are several methods to solve a quadratic equation:\n'
#              '\n'
#              '1. **Factoring**:\n'
#              '   - This involves rewriting the equation as a product of two '
#              'binomials. For example: \n'
#              '     \\[x^2 - 5x + 6 = (x - 2)(x - 3) = 0\\]\n'
#              '   - Setting each factor to zero gives you the solutions: \\(x - '
#              '2 = 0\\) and \\(x - 3 = 0\\) results in \\(x = 2\\) and \\(x = '
#              '3\\).\n'
#              '\n'
#              '2. **Completing the Square**:\n'
#              '   - Rewrite the equation in the form \\((x - p)^2 = q\\), then '
#              'solve for \\(x\\).\n'
#              '   - For example: \\( x^2 + 6x + 5 = 0 \\)\n'
#              '     First, move the constant term to the other side: \\( x^2 + '
#              '6x = -5 \\)\n'
#              '     Next, add \\((\\frac{b}{2})^2\\) to both sides, where '
#              '\\(b\\) is the coefficient of \\(x\\): \n'
#              '     \\( x^2 + 6x + 9 = -5 + 9 \\)\n'
#              '     \\( (x + 3)^2 = 4 \\)\n'
#              '     Take the square root of both sides: \\( x + 3 = \\pm 2 \\)\n'
#              '     Finally, solve for \\(x\\): \\( x = -3 \\pm 2 \\), so \\( x '
#              '= -1 \\) or \\( x = -5 \\).\n'
#              '\n'
#              '3. **Using the Quadratic Formula**:\n'
#              '   - This is a formula that provides the solutions directly. It '
#              'is:\n'
#              '     \\[\n'
#              '     x = \\frac{-b \\pm \\sqrt{b^2 - 4ac}}{2a}\n'
#              '     \\]\n'
#              '   - For example, if \\(a = 1\\), \\(b = -3\\), and \\(c = '
#              '2\\):\n'
#              '     \\[\n'
#              '     x = \\frac{-(-3) \\pm \\sqrt{(-3)^2 - 4 \\cdot 1 \\cdot '
#              '2}}{2 \\cdot 1} \n'
#              '     = \\frac{3 \\pm \\sqrt{9 - 8}}{2} \n'
#              '     = \\frac{3 \\pm 1}{2}\n'
#              '     \\]\n'
#              '     So, \\(x = \\frac{4}{2} = 2 \\) or \\(x = \\frac{2}{2} = '
#              '1\\).\n'
#              '\n'
#              '4. **Graphing**:\n'
#              '   - Quadratic equations represent parabolas when graphed. The '
#              'solutions are the x-values where the parabola intersects the '
#              'x-axis (the roots of the equation).\n'
#              '\n'
#              '### Discriminant\n'
#              '\n'
#              'The discriminant in the quadratic equation is \\( \\Delta = b^2 '
#              '- 4ac \\):\n'
#              '- If \\( \\Delta > 0 \\), there are two distinct real '
#              'solutions.\n'
#              '- If \\( \\Delta = 0 \\), there is one real solution.\n'
#              '- If \\( \\Delta < 0 \\), there are no real solutions, but two '
#              'complex solutions.\n'
#              '\n'
#              'Would you like to work through a specific example together to '
#              'see how these methods are applied?',
#   'role': 'assistant'},
#  {'content': "Absolutely, let's work through a specific example together. How "
#              'about we solve the quadratic equation \\(2x^2 - 4x - 6 = 0\\)? '
#              "We'll apply the methods we've discussed to solve it.\n"
#              '\n'
#              '### Step-by-Step Example\n'
#              '\n'
#              '#### 1. Factoring\n'
#              'Factoring can occasionally be more challenging if the equation '
#              "doesn't easily break down into binomials. In this particular "
#              "equation, factoring isn't straightforward, so let's move on to "
#              'another method.\n'
#              '\n'
#              '#### 2. Completing the Square\n'
#              '\n'
#              'To complete the square, we start by rearranging the equation:\n'
#              '\n'
#              '\\[ 2x^2 - 4x - 6 = 0 \\]\n'
#              '\n'
#              'First, divide every term by \\(2\\) to simplify the equation:\n'
#              '\n'
#              '\\[ x^2 - 2x - 3 = 0 \\]\n'
#              '\n'
#              'Next, move the constant term to the other side:\n'
#              '\n'
#              '\\[ x^2 - 2x = 3 \\]\n'
#              '\n'
#              'Now add \\((\\frac{b}{2})^2\\) to both sides, where \\(b = '
#              '-2\\):\n'
#              '\n'
#              '\\[ x^2 - 2x + 1 = 3 + 1 \\]\n'
#              '\n'
#              'Notice how we turned the left side into a perfect square '
#              'trinomial:\n'
#              '\n'
#              '\\[ (x - 1)^2 = 4 \\]\n'
#              '\n'
#              'To solve for \\(x\\), take the square root of both sides:\n'
#              '\n'
#              '\\[ x - 1 = \\pm 2 \\]\n'
#              '\n'
#              'Thus, \\(x\\) can be:\n'
#              '\n'
#              '\\[ x - 1 = 2 \\implies x = 3 \\]\n'
#              '\\[ x - 1 = -2 \\implies x = -1 \\]\n'
#              '\n'
#              'So, the solutions are \\(x = 3\\) and \\(x = -1\\).\n'
#              '\n'
#              '#### 3. Using the Quadratic Formula\n'
#              '\n'
#              "Now let's apply the quadratic formula:\n"
#              '\n'
#              '\\[ x = \\frac{-b \\pm \\sqrt{b^2 - 4ac}}{2a} \\]\n'
#              '\n'
#              'Given our original equation \\(2x^2 - 4x - 6 = 0\\), identify '
#              'the coefficients \\(a = 2\\), \\(b = -4\\), and \\(c = -6\\):\n'
#              '\n'
#              '\\[ x = \\frac{-(-4) \\pm \\sqrt{(-4)^2 - 4 \\cdot 2 \\cdot '
#              '(-6)}}{2 \\cdot 2} \\]\n'
#              '\n'
#              'Simplify inside the square root:\n'
#              '\n'
#              '\\[ x = \\frac{4 \\pm \\sqrt{16 + 48}}{4} \\]\n'
#              '\\[ x = \\frac{4 \\pm \\sqrt{64}}{4} \\]\n'
#              '\\[ x = \\frac{4 \\pm 8}{4} \\]\n'
#              '\n'
#              'This gives us two solutions:\n'
#              '\n'
#              '\\[ x = \\frac{4 + 8}{4} = \\frac{12}{4} = 3 \\]\n'
#              '\\[ x = \\frac{4 - 8}{4} = \\frac{-4}{4} = -1 \\]\n'
#              '\n'
#              'So, the solutions are indeed \\(x = 3\\) and \\(x = -1\\), '
#              'consistent with our previous method.\n'
#              '\n'
#              '#### 4. Graphing\n'
#              '\n'
#              'When we graph \\(2x^2 - 4x - 6 = 0\\), we would plot the '
#              'parabola represented by the equation \\(y = 2x^2 - 4x - 6\\). '
#              'The points where the parabola intersects the x-axis will be at '
#              '\\(x = 3\\) and \\(x = -1\\).\n'
#              '\n'
#              '### Summary\n'
#              '\n'
#              "We've verified that the solutions to the quadratic equation "
#              '\\(2x^2 - 4x - 6 = 0\\) are \\(x = 3\\) and \\(x = -1\\) using '
#              'both completing the square and the quadratic formula. Factoring '
#              "didn't work straightforwardly, which can happen, but you always "
#              'have multiple tools to tackle these problems.\n'
#              '\n'
#              'Would you like to go through another example or have any '
#              'specific questions about what we covered?',
#   'role': 'user'}]

# %%
pprint.pprint(result.cost)
# Out:
# {'usage_excluding_cached_inference': {'total_cost': 0},
#  'usage_including_cached_inference': {'gpt-4o-2024-05-13': {'completion_tokens': 2538,
#                                                             'cost': 0.051805000000000004,
#                                                             'prompt_tokens': 2747,
#                                                             'total_tokens': 5285},
#                                       'total_cost': 0.051805000000000004}}

# %%
pprint.pprint(result.summary)
# Out:
# ("Absolutely, let's work through a specific example together. How about we "
#  "solve the quadratic equation \\(2x^2 - 4x - 6 = 0\\)? We'll apply the "
#  "methods we've discussed to solve it.\n"
#  '\n'
#  '### Step-by-Step Example\n'
#  '\n'
#  '#### 1. Factoring\n'
#  "Factoring can occasionally be more challenging if the equation doesn't "
#  'easily break down into binomials. In this particular equation, factoring '
#  "isn't straightforward, so let's move on to another method.\n"
#  '\n'
#  '#### 2. Completing the Square\n'
#  '\n'
#  'To complete the square, we start by rearranging the equation:\n'
#  '\n'
#  '\\[ 2x^2 - 4x - 6 = 0 \\]\n'
#  '\n'
#  'First, divide every term by \\(2\\) to simplify the equation:\n'
#  '\n'
#  '\\[ x^2 - 2x - 3 = 0 \\]\n'
#  '\n'
#  'Next, move the constant term to the other side:\n'
#  '\n'
#  '\\[ x^2 - 2x = 3 \\]\n'
#  '\n'
#  'Now add \\((\\frac{b}{2})^2\\) to both sides, where \\(b = -2\\):\n'
#  '\n'
#  '\\[ x^2 - 2x + 1 = 3 + 1 \\]\n'
#  '\n'
#  'Notice how we turned the left side into a perfect square trinomial:\n'
#  '\n'
#  '\\[ (x - 1)^2 = 4 \\]\n'
#  '\n'
#  'To solve for \\(x\\), take the square root of both sides:\n'
#  '\n'
#  '\\[ x - 1 = \\pm 2 \\]\n'
#  '\n'
#  'Thus, \\(x\\) can be:\n'
#  '\n'
#  '\\[ x - 1 = 2 \\implies x = 3 \\]\n'
#  '\\[ x - 1 = -2 \\implies x = -1 \\]\n'
#  '\n'
#  'So, the solutions are \\(x = 3\\) and \\(x = -1\\).\n'
#  '\n'
#  '#### 3. Using the Quadratic Formula\n'
#  '\n'
#  "Now let's apply the quadratic formula:\n"
#  '\n'
#  '\\[ x = \\frac{-b \\pm \\sqrt{b^2 - 4ac}}{2a} \\]\n'
#  '\n'
#  'Given our original equation \\(2x^2 - 4x - 6 = 0\\), identify the '
#  'coefficients \\(a = 2\\), \\(b = -4\\), and \\(c = -6\\):\n'
#  '\n'
#  '\\[ x = \\frac{-(-4) \\pm \\sqrt{(-4)^2 - 4 \\cdot 2 \\cdot (-6)}}{2 \\cdot '
#  '2} \\]\n'
#  '\n'
#  'Simplify inside the square root:\n'
#  '\n'
#  '\\[ x = \\frac{4 \\pm \\sqrt{16 + 48}}{4} \\]\n'
#  '\\[ x = \\frac{4 \\pm \\sqrt{64}}{4} \\]\n'
#  '\\[ x = \\frac{4 \\pm 8}{4} \\]\n'
#  '\n'
#  'This gives us two solutions:\n'
#  '\n'
#  '\\[ x = \\frac{4 + 8}{4} = \\frac{12}{4} = 3 \\]\n'
#  '\\[ x = \\frac{4 - 8}{4} = \\frac{-4}{4} = -1 \\]\n'
#  '\n'
#  'So, the solutions are indeed \\(x = 3\\) and \\(x = -1\\), consistent with '
#  'our previous method.\n'
#  '\n'
#  '#### 4. Graphing\n'
#  '\n'
#  'When we graph \\(2x^2 - 4x - 6 = 0\\), we would plot the parabola '
#  'represented by the equation \\(y = 2x^2 - 4x - 6\\). The points where the '
#  'parabola intersects the x-axis will be at \\(x = 3\\) and \\(x = -1\\).\n'
#  '\n'
#  '### Summary\n'
#  '\n'
#  "We've verified that the solutions to the quadratic equation \\(2x^2 - 4x - 6 "
#  '= 0\\) are \\(x = 3\\) and \\(x = -1\\) using both completing the square and '
#  "the quadratic formula. Factoring didn't work straightforwardly, which can "
#  'happen, but you always have multiple tools to tackle these problems.\n'
#  '\n'
#  'Would you like to go through another example or have any specific questions '
#  'about what we covered?')

# %% [markdown]
# ## Terminating condition - `is_termination_msg`

# %%
student = ConversableAgent(
    "student",
    system_message="You are a high school student struggling with algebra. You need help understanding quadratic equations.",
    llm_config={
        "config_list": config_list
    },
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "exit" in msg["content"],
)

tutor = ConversableAgent(
    "tutor",
    system_message='''
        You are a patient and knowledgeable math tutor. 
        Your goal is to help students understand algebra concepts, particularly quadratic equations.
        ''',
    llm_config={
        "config_list": config_list
    },
    human_input_mode="NEVER",
)
# Out:
# [autogen.oai.client: 09-28 01:37:02] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 09-28 01:37:02] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.

# %%
result = student.initiate_chat(
    tutor,
    message="I'm really struggling with quadratic equations. Can you help me understand them better and then say exit?",
)
# Out:
# student (to tutor):
#
# I'm really struggling with quadratic equations. Can you help me understand them better and then say exit?
#
# --------------------------------------------------------------------------------
# tutor (to student):
#
# Absolutely, I can help you understand quadratic equations better!
#
# ### Introduction to Quadratic Equations
#
# A quadratic equation is a second-degree polynomial equation in a single variable \( x \) with the general form:
# \[ ax^2 + bx + c = 0 \]
# where:
# - \( a \), \( b \), and \( c \) are constants,
# - \( a \neq 0 \) (because if \( a \) were 0, it would not be a quadratic equation).
#
# ### Key Features
#
# 1. **Standard Form**: The equation \( ax^2 + bx + c = 0 \) is in standard form.
# 2. **Quadratic Term**: \( ax^2 \) (the term with the variable squared).
# 3. **Linear Term**: \( bx \) (the term with the variable to the first power).
# 4. **Constant Term**: \( c \) (the term with no variable).
#
# ### Solving Quadratic Equations
#
# There are several methods to solve quadratic equations:
#
# #### 1. Factoring
# This method works when the quadratic can be factored into two binomials.
# Example:
# \[ x^2 - 5x + 6 = 0 \]
# It can be factored into:
# \[ (x - 2)(x - 3) = 0 \]
# Setting each factor to zero gives the solutions:
# \[ x - 2 = 0 \quad \text{or} \quad x - 3 = 0 \]
# Thus,
# \[ x = 2 \quad \text{or} \quad x = 3 \]
#
# #### 2. Completing the Square
# This method transforms the quadratic into a perfect square trinomial.
# Example:
# \[ x^2 + 6x + 5 = 0 \]
# First, move the constant term to the other side:
# \[ x^2 + 6x = -5 \]
# Add the square of half the coefficient of \( x \) (which is \( (6/2)^2 = 9 \)) to both sides:
# \[ x^2 + 6x + 9 = 4 \]
# \[ (x + 3)^2 = 4 \]
# Taking the square root of both sides gives:
# \[ x + 3 = \pm 2 \]
# Thus,
# \[ x = -1 \quad \text{or} \quad x = -5 \]
#
# #### 3. Quadratic Formula
# The quadratic formula can solve any quadratic equation:
# \[ x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} \]
# Example:
# For the equation \( 2x^2 + 3x - 2 = 0 \):
# Identify \( a = 2 \), \( b = 3 \), and \( c = -2 \).
# Substitute into the formula:
# \[ x = \frac{-3 \pm \sqrt{3^2 - 4(2)(-2)}}{2(2)} \]
# \[ x = \frac{-3 \pm \sqrt{9 + 16}}{4} \]
# \[ x = \frac{-3 \pm \sqrt{25}}{4} \]
# \[ x = \frac{-3 \pm 5}{4} \]
# So, the solutions are:
# \[ x = \frac{2}{4} = \frac{1}{2} \quad \text{or} \quad x = \frac{-8}{4} = -2 \]
#
# #### 4. Graphing
# You can also solve quadratic equations by graphing the quadratic function \( y = ax^2 + bx + c \) and finding the x-values where the graph intersects the x-axis.
#
# ### Summary
#
# - **Quadratic equations** are polynomials of degree 2.
# - **Methods to solve** include factoring, completing the square, the quadratic formula, and graphing.
# - **Quadratic formula**: \( x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} \)
# - **Solutions** (also known as roots) can be real or complex numbers, and a quadratic equation always has 2 solutions (though some solutions may be repeated).
#
# I hope this helps clarify how to tackle quadratic equations! If you have any specific questions or need more examples, feel free to ask.
#
# exit
#
# --------------------------------------------------------------------------------
