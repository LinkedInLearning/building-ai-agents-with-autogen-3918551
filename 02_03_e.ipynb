# %% [markdown]
# # 02_02 - Research Assistant Design

# %%
## import required libraries
import os
from autogen import ConversableAgent, UserProxyAgent
from dotenv import load_dotenv


load_dotenv() # load environment variables from .env file
# Out:
# False

# %%
## llm configuration
llm_config ={
                "model": "gpt-4o",
                "api_key": os.getenv("OPENAI_API_KEY")
            }

# %% [markdown]
# ## Manager Proxy Agent

# %%
manager_proxy_agent = UserProxyAgent(
    name="Manager",
    system_message="You are a marketing campaign manager. Your role is to provide campaign topics and evaluate the ideas and scripts generated by the creative team.",
    human_input_mode="TERMINATE",
    llm_config=llm_config,
)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 manager_proxy_agent = UserProxyAgent(
#       2     name="Manager",
#       3     system_message="You are a marketing campaign manager. Your role is to provide campaign topics and evaluate the ideas and scripts generated by the creative team.",
#       4     human_input_mode="TERMINATE",
#       5     llm_config=llm_config,
#       6 )
#
# File ~/lil/building-ai-agents-with-autogen-3918551/.autogen_env/lib/python3.12/site-packages/autogen/agentchat/user_proxy_agent.py:86, in UserProxyAgent.__init__(self, name, is_termination_msg, max_consecutive_auto_reply, human_input_mode, function_map, code_execution_config, default_auto_reply, llm_config, system_message, description, **kwargs)
#      26 def __init__(
#      27     self,
#      28     name: str,
#    (...)
#      38     **kwargs,
#      39 ):
#      40     """
#      41     Args:
#      42         name (str): name of the agent.
#    (...)
#      84             [ConversableAgent](conversable_agent#__init__).
#      85     """
# ---> 86     super().__init__(
#      87         name=name,
#      88         system_message=system_message,
#      89         is_termination_msg=is_termination_msg,
#      90         max_consecutive_auto_reply=max_consecutive_auto_reply,
#      91         human_input_mode=human_input_mode,
#      92         function_map=function_map,
#      93         code_execution_config=code_execution_config,
#      94         llm_config=llm_config,
#      95         default_auto_reply=default_auto_reply,
#      96         description=(
#      97             description if description is not None else self.DEFAULT_USER_PROXY_AGENT_DESCRIPTIONS[human_input_mode]
#      98         ),
#      99         **kwargs,
#     100     )
#     102     if logging_enabled():
#     103         log_new_agent(self, locals())
#
# File ~/lil/building-ai-agents-with-autogen-3918551/.autogen_env/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:164, in ConversableAgent.__init__(self, name, system_message, is_termination_msg, max_consecutive_auto_reply, human_input_mode, function_map, code_execution_config, llm_config, default_auto_reply, description, chat_messages, silent)
#     158     except TypeError as e:
#     159         raise TypeError(
#     160             "Please implement __deepcopy__ method for each value class in llm_config to support deepcopy."
#     161             " Refer to the docs for more details: https://microsoft.github.io/autogen/docs/topics/llm_configuration#adding-http-client-in-llm_config-for-proxy"
#     162         ) from e
# --> 164 self._validate_llm_config(llm_config)
#     166 if logging_enabled():
#     167     log_new_agent(self, locals())
#
# File ~/lil/building-ai-agents-with-autogen-3918551/.autogen_env/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:268, in ConversableAgent._validate_llm_config(self, llm_config)
#     264 if self.llm_config in [{}, {"config_list": []}, {"config_list": [{"model": ""}]}]:
#     265     raise ValueError(
#     266         "When using OpenAI or Azure OpenAI endpoints, specify a non-empty 'model' either in 'llm_config' or in each config of 'config_list'."
#     267     )
# --> 268 self.client = None if self.llm_config is False else OpenAIWrapper(**self.llm_config)
#
# File ~/lil/building-ai-agents-with-autogen-3918551/.autogen_env/lib/python3.12/site-packages/autogen/oai/client.py:427, in OpenAIWrapper.__init__(self, config_list, **base_config)
#     423         self._config_list.append(
#     424             {**extra_kwargs, **{k: v for k, v in config.items() if k not in self.openai_kwargs}}
#     425         )
#     426 else:
# --> 427     self._register_default_client(extra_kwargs, openai_config)
#     428     self._config_list = [extra_kwargs]
#     429 self.wrapper_id = id(self)
#
# File ~/lil/building-ai-agents-with-autogen-3918551/.autogen_env/lib/python3.12/site-packages/autogen/oai/client.py:526, in OpenAIWrapper._register_default_client(self, config, openai_config)
#     524     self._clients.append(client)
#     525 else:
# --> 526     client = OpenAI(**openai_config)
#     527     self._clients.append(OpenAIClient(client))
#     529 if logging_enabled():
#
# File ~/lil/building-ai-agents-with-autogen-3918551/.autogen_env/lib/python3.12/site-packages/openai/_client.py:105, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     103     api_key = os.environ.get("OPENAI_API_KEY")
#     104 if api_key is None:
# --> 105     raise OpenAIError(
#     106         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     107     )
#     108 self.api_key = api_key
#     110 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %% [markdown]
# ## Idea Generator Agent

# %%
idea_generator = ConversableAgent(
    name="Idea Generator",
    system_message='''You are a creative marketing expert. Your role is to:
    1. Generate innovative campaign ideas based on the given topic
    2. Suggest potential storylines and characters for video content
    3. Provide a brief outline for each idea
    Present 3-5 unique ideas for each request.''',
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# %% [markdown]
# ## Script Writer Agent

# %%
script_writer = ConversableAgent(
    name="Script Writer",
    system_message='''You are an expert script writer for marketing videos. Your role is to:
    1. Develop full scripts based on the provided campaign ideas
    2. Include dialogue, scene descriptions, and camera directions
    3. Ensure the script aligns with the campaign objectives and target audience
    Aim for scripts of 2-3 minutes in length.''',
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# %% [markdown]
# ## Script Reviewer Agent

# %%
script_reviewer = ConversableAgent(
    name="Script Reviewer",
    system_message='''You are a critical script reviewer. Your role is to:
    1. Analyze scripts for effectiveness, engagement, and alignment with campaign goals
    2. Provide constructive feedback on dialogue, pacing, and overall structure
    3. Suggest improvements or alternatives where necessary
    4. Ensure the script adheres to brand guidelines and target audience preferences
    Be thorough and specific in your feedback.''',
    llm_config=llm_config,
    human_input_mode="NEVER"
)
